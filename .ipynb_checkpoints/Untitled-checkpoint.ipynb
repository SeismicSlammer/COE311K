# %%
baseTenNumber = 45
while (baseTenNumber/2)>1:
    print(baseTenNumber%2)
    baseTenNumber = baseTenNumber - baseTenNumber%2
    baseTenNumber = baseTenNumber/2
if baseTenNumber == 2:
    print(0)
    print(1)
if baseTenNumber == 0:
    print(0)
if baseTenNumber== 1:
    print(1)
# Out:
# 1
# 0.0
# 1.0
# 1.0
# 0
# 1
