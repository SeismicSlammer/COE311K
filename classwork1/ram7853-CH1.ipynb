# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x =np.linspace(0,2*np.pi,50)
plt.subplot(2,2,1)
plt.plot(x,np.sin(x),'k''_')
plt.subplot(2,2,2)
plt.plot(x,np.tan(x),'red')
plt.subplot(2,2,3)
plt.plot(x,x*x,'m' '^')
y=np.cos(x)
x=np.sin(x)
plt.subplot(2,2,4)
size = np.random.rand(50) * 50
color = np.random.rand(50)
plt.scatter(x, y, size, color)
